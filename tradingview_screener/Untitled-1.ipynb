# %%
from tradingview_screener import Query

from tradingview_screener.column import Column
Query().get_scanner_data()
# Out:
# (17462,
#            ticker   name      close     volume  market_cap_basic
#  0    NASDAQ:NVDA   NVDA     106.21  372458951      2.605331e+12
#  1       AMEX:SPY    SPY     550.95   47224929               NaN
#  2    NASDAQ:TSLA   TSLA     219.41   80651564      7.009361e+11
#  3     NASDAQ:QQQ    QQQ     460.61   32503952               NaN
#  4    NASDAQ:AAPL   AAPL     220.85   43840082      3.357834e+12
#  5    NASDAQ:MSFT   MSFT     408.90   15135765      3.039369e+12
#  6     NASDAQ:AMD    AMD     140.87   42130643      2.279956e+11
#  7    NASDAQ:AMZN   AMZN     173.33   30309184      1.819197e+12
#  8       AMEX:IWM    IWM     212.99   23706204               NaN
#  9    NASDAQ:META   META     512.74    8335206      1.297138e+12
#  10    NASDAQ:TLT    TLT      99.01   40884469               NaN
#  11      AMEX:LQD    LQD     111.83   31897861               NaN
#  12     AMEX:SOXL   SOXL      30.30  108756639               NaN
# ...

# %%
Query().select('close', 'volume', 'EMA5', 'EMA20', 'type').where(Column('close').between(Column('EMA5'), Column('EMA20')),Column('type')
       .isin(['stock'])).order_by('volume', ascending=False).get_scanner_data_raw()
# Out:
# {'totalCount': 804,
#  'data': [{'s': 'NASDAQ:LGMK',
#    'd': [0.2079, 99827017, 0.19248333707841786, 0.22517002845111286, 'stock']},
#   {'s': 'NASDAQ:FFIE',
#    'd': [5.24, 69568838, 5.098827761636225, 6.968544075366575, 'stock']},
#   {'s': 'OTC:TMSH',
#    'd': [0.0002,
#     50038583,
#     0.0001969343825808479,
#     0.00020994359790737653,
#     'stock']},
#   {'s': 'NASDAQ:FCEL',
#    'd': [0.411, 18575063, 0.4085114209490358, 0.44550372087872314, 'stock']},
#   {'s': 'OTC:SMCE',
#    'd': [0.0026,
#     15390124,
#     0.0023855060307294645,
#     0.002621303089693853,
#     'stock']},
#   {'s': 'NASDAQ:JBLU',
#    'd': [5.03, 15058438, 4.9932896454703535, 5.073604844018657, 'stock']},
#   {'s': 'OTC:SFLM',
#    'd': [0.00025,
#     14600075,
#     0.00024294781786256977,
#     0.00026430640045300746,
#     'stock']},
#   {'s': 'OTC:NWPN',
#    'd': [0.0001,
#     13484000,
#     9.99693451583233e-05,
#     0.00010511884643887825,
#     'stock']},
# ...
